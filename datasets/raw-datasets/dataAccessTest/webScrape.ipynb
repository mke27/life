# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://ec.europa.eu/economy_finance/country-specific-recommendations-database/'
response = requests.get(url).text

# %%
soup = BeautifulSoup(response)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <!-- <link rel="stylesheet" href="https://ec2-3-92-185-52.compute-1.amazonaws.com/anon/resources/autogenerated/qlik-styles.css"> -->
# <link href="public/websy-designs.min.css" rel="stylesheet"/>
# <link href="https://v3--europa-component-library.netlify.app/playground/ec/styles/ecl-ec.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://cdn1.fpfis.tech.ec.europa.eu/ecl/v2.39.0/ec-preset-website/styles/ecl-ec-preset-website.css" integrity="sha256-5gtjJdzhQj/6dDgp8U5pEU79zmJt3tOZXtU9KGiPckM= sha384-ERo8XH/B7LiOKgppaZUgZcAXFYmnG9YmFGVXJL8GLRmrIdRJ+25EyMgqQlAHX7tk sha512-iml+ef18jNra9w1C9uT45dQEcC2Mjun2X4Em88F/sA6hpktGuvb5Rug/cQK/uQFACW3gxo4dZMOgFjov7i44qA==" media="screen" rel="stylesheet"/>
# ...

# %%
# finds the first table on the website
out_of_main = soup.find("div", id='content')
content = BeautifulSoup(str(out_of_main))
one_step_closer = content.find("div",id='dataView')
better = BeautifulSoup(str(one_step_closer))

#pd.read_html(str(table))[0]
# Out:
# <div class="csr-view" id="dataView">
# <div class="ecl-container">
# <div class="ecl-row">
# <div class="ecl-col-7">
# <div class="spacer"></div>
# <div id="radioOptions"></div>
# </div>
# <div class="ecl-col-5">
# <div class="spacer"></div>
# <div class="text-right csr-export-buttons">
# <button class="ecl-button ecl-button--call" onclick="downloadData()">Export Search</button>
# <button class="ecl-button ecl-button--primary" onclick="downloadAllData()">Export Full Database</button>
# </div>
# </div>
# </div>
# </div>
# <div class="ecl-container ecl-container-fluid">
# <div class="ecl-row">
# <div class="csr-chart-cont-card csr-chart-cont show">
# <div class="ecl-col-l-12 ecl-col-m-12">
# <div class="spacer"></div>
# <div class="ecl-chart-object" id="table"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
